# %% [markdown]
# # MGPEB – Módulo de Gerenciamento de Pouso e Estabilização de Base
#
# Projeto desenvolvido para simular o controle de pouso de módulos em uma colônia em Marte.

# %% [markdown]
# ## 1.1 Cenário de pouso
#
# A missão Aurora Siger possui diferentes módulos que precisam pousar em Marte.
#
# Os módulos definidos são:
# - Habitação
# - Energia
# - Laboratório
# - Logística
# - Médico
#
# Cada módulo possui:
# - prioridade
# - combustível
# - massa
# - criticidade
# - horário de chegada

# %% [markdown]
# ## 1.2 Estruturas de dados
#
# - Fila: módulos aguardando pouso
# - Lista: módulos já pousados
# - Pilha: módulos em alerta

# %%
import random

# Estruturas
fila_pouso = []
pousados = []
alerta = []

# Condições externas
clima_ok = random.choice([True, False])
sensores_ok = random.choice([True, True, True, False])

print("CONDIÇÕES DO SISTEMA:")
print("Clima favorável:", clima_ok)
print("Sensores operacionais:", sensores_ok)
print("-" * 40)

# Módulos
modulos = [
    {"nome": "Habitação", "prioridade": random.randint(3,5), "combustivel": random.randint(40,100)},
    {"nome": "Energia", "prioridade": random.randint(3,5), "combustivel": random.randint(40,100)},
    {"nome": "Laboratório", "prioridade": random.randint(1,4), "combustivel": random.randint(40,100)},
    {"nome": "Logística", "prioridade": random.randint(1,3), "combustivel": random.randint(40,100)},
    {"nome": "Médico", "prioridade": random.randint(3,5), "combustivel": random.randint(40,100)}
]

# Fila
for m in modulos:
    fila_pouso.append(m)

# Mostrar dados
print("\nDADOS DOS MÓDULOS:\n")
for m in fila_pouso:
    print(m)

print("-" * 40)

# Ordenação
fila_pouso.sort(key=lambda x: x["prioridade"], reverse=True)

# Busca
def buscar_menor_combustivel(lista):
    menor = lista[0]
    for m in lista:
        if m["combustivel"] < menor["combustivel"]:
            menor = m
    return menor

# Regras
def autorizar_pouso(modulo):
    combustivel_ok = modulo["combustivel"] > 50
    prioridade_alta = modulo["prioridade"] >= 4

    if (combustivel_ok and sensores_ok and clima_ok) or prioridade_alta:
        return True
    else:
        return False

# Simulação
print("\nINICIANDO GERENCIAMENTO DE POUSO\n")

while fila_pouso:
    modulo = fila_pouso.pop(0)

    print("Analisando módulo:", modulo["nome"])
    print("Combustível:", modulo["combustivel"], "| Prioridade:", modulo["prioridade"])

    if autorizar_pouso(modulo):
        print("Pouso autorizado\n")
        pousados.append(modulo)
    else:
        print("Pouso negado - enviado para alerta\n")
        alerta.append(modulo)

# Resultado
print("\n--- RESULTADO FINAL ---")

print("\nMódulos pousados:")
for m in pousados:
    print("-", m["nome"])

print("\nMódulos em alerta:")
for m in alerta:
    print("-", m["nome"])

# Busca final
menor = buscar_menor_combustivel(modulos)
print("\nMódulo com menor combustível:", menor["nome"])
# Out:
# CONDIÇÕES DO SISTEMA:
# Clima favorável: False
# Sensores operacionais: False
# ----------------------------------------
#
# DADOS DOS MÓDULOS:
#
# {'nome': 'Habitação', 'prioridade': 3, 'combustivel': 96}
# {'nome': 'Energia', 'prioridade': 4, 'combustivel': 50}
# {'nome': 'Laboratório', 'prioridade': 1, 'combustivel': 64}
# {'nome': 'Logística', 'prioridade': 3, 'combustivel': 65}
# {'nome': 'Médico', 'prioridade': 3, 'combustivel': 56}
# ----------------------------------------
#
# INICIANDO GERENCIAMENTO DE POUSO
#
# Analisando módulo: Energia
# Combustível: 50 | Prioridade: 4
# Pouso autorizado
#
# Analisando módulo: Habitação
# Combustível: 96 | Prioridade: 3
# Pouso negado - enviado para alerta
#
# Analisando módulo: Logística
# Combustível: 65 | Prioridade: 3
# Pouso negado - enviado para alerta
#
# Analisando módulo: Médico
# Combustível: 56 | Prioridade: 3
# Pouso negado - enviado para alerta
#
# Analisando módulo: Laboratório
# Combustível: 64 | Prioridade: 1
# ...

# %% [markdown]
# ## 1.4 Regras de decisão
#
# O pouso é autorizado quando:
#
# (combustível > 50 AND sensores OK AND clima OK)
# OU
# (prioridade alta)
#
# Representação:
#
# (Combustível AND Sensores AND Clima) OR Prioridade

# %% [markdown]
# ## 1.5 Modelagem matemática
#
# C(t) = C0 - k*t
#
# Onde:
# - C(t): combustível restante
# - C0: inicial
# - k: consumo
# - t: tempo
#
# Quanto maior o tempo, menor o combustível disponível.

# %% [markdown]
# ## 1.6 Evolução da computação
#
# A evolução da computação permitiu o desenvolvimento de sistemas cada vez mais confiáveis e eficientes. Os primeiros computadores ocupavam grandes espaços e possuíam baixo poder de processamento, enquanto hoje sistemas embarcados são capazes de realizar milhões de operações em ambientes extremos, como o espaço.
#
# Em uma missão em Marte, existem limitações importantes, como baixo consumo de energia, resistência à radiação e memória limitada. Isso exige o uso de algoritmos simples e eficientes, além de estruturas de dados organizadas, como listas e filas.
#
# O MGPEB segue esse princípio, utilizando lógica simples e direta para garantir confiabilidade nas decisões de pouso.

# %% [markdown]
# ## 1.7 ESG
#
# A base Aurora Siger deve operar seguindo princípios de sustentabilidade e responsabilidade. A escolha da área de pouso deve considerar impactos ambientais no solo marciano, evitando regiões de interesse científico.
#
# A gestão de recursos deve ser eficiente, priorizando o uso de energia solar e reaproveitamento de materiais. Além disso, decisões devem ser tomadas com transparência, garantindo que a tecnologia seja utilizada de forma ética.
#
# Mesmo em um ambiente extremo como Marte, a governança deve assegurar equilíbrio entre desenvolvimento tecnológico e preservação.

# %% [markdown]
# ## lRepositório de projeto
#
# O código completo do projeto está disponível no Github:
